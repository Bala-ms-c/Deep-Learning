# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding

# Sample dataset: Training on sequences of numbers (1-100)
X = np.array([[i, i+1, i+2] for i in range(1, 98)])
Y = np.array([[i+3] for i in range(1, 98)])

# Reshape data to fit RNN input format
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build the RNN model
model = Sequential([
    SimpleRNN(50, activation='relu', return_sequences=False, input_shape=(3, 1)),
    Dense(1)
])

# Compile and train the model
model.compile(optimizer='adam', loss='mse')
model.fit(X, Y, epochs=50, verbose=1)

# Test the model
test_input = np.array([[97, 98, 99]]).reshape((1, 3, 1))
prediction = model.predict(test_input)
print(f"Predicted Next Number: {prediction}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 8762.1719
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6040.6353
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4366.7354
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3056.3425
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1591.6344
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 806.9645
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 314.2391
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 73.1001
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7163
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 21.5120
# ...
